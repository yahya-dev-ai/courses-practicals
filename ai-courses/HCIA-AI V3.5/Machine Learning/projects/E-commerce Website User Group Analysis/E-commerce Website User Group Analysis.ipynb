# %% [markdown]
# # 🚀 E-commerce Website User Group Analysis

# %% [markdown]
# ## 📝 Introduction & Objectives

# %% [markdown]
# <details>
# <summary><strong>🔍 Project Overview</strong></summary>
#
# A **k-means clustering model** is used to group users into categories based on their behavior, with a focus on finding the optimal number of clusters.
#
# </details>
#
# <details>
# <summary><strong>🎯 Benefits of User Group Analysis</strong></summary>
#
# - 📝 **Improves marketing strategies through targeted campaigns**
#   - _e.g., creating personalized offers for different user groups_
# - 💡 **Supports product development by understanding user needs**
#   - _e.g., identifying features that are most important to specific user segments_
# - 🎯 **Enhances user experience by tailoring the website to user preferences**
#   - _e.g., recommending products based on the user's group_
# - 🔄 **Provides value to both users and the business**
#   - _e.g., users get a more personalized experience, and the business increases sales_
#
# </details>

# %% [markdown]
# ## 🛠️ Data Loading and Initial Exploration

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# Generate synthetic user data
X, _ = make_blobs(n_samples=2000, centers=[(0,0),(4,5)], cluster_std=1.0, random_state=42)
print("Data shape:", X.shape)

# Show first 5 rows
print(X[:5])
# Out:
# Data shape: (2000, 2)
# [[ 4.18383452  7.69303366]
#  [ 1.8820245   1.34542005]
#  [-1.41836573 -1.76080881]
#  [ 5.26370668  4.15368402]
#  [-0.65183611  0.04739867]]

# %%
# Check the shape of the data
X.shape
# Out:
# (2000, 2)

# %% [markdown]
# ## ⚙️ Data Preprocessing & Feature Engineering

# %%
# For synthetic data, preprocessing is minimal
# If using real user data, add scaling, encoding, or feature engineering here

# %% [markdown]
# ## 🧠 Model Training

# %%
from sklearn.cluster import KMeans

# Train K-means model
kmeans = KMeans(n_clusters=5, random_state=3)
y = kmeans.fit_predict(X)

# Visualize clustering results
fig, ax = plt.subplots(1,2, figsize=(10,6), sharex=True, sharey=True)
ax[0].scatter(X[:,0], X[:,1], s=10); ax[0].set_title("Raw Data")
ax[1].scatter(X[:,0], X[:,1], c=y, s=10, cmap="viridis"); ax[1].set_title("KMeans (k=5)")
plt.tight_layout(); plt.show()

# %% [markdown]
# ## 📈 Model Evaluation

# %%
# Elbow method to find optimal k
inertia = []
k_values = range(1, 11)
for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(X)
    inertia.append(kmeans.inertia_)

plt.plot(k_values, inertia, marker='o')
plt.title("Elbow Method for Optimal k")
plt.xlabel("Number of Clusters")
plt.ylabel("Inertia")
plt.grid()
plt.show()
